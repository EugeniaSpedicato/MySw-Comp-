# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib
import matplotlib.pyplot as plt
import xgboost as xgb
from ann_visualizer.visualize import ann_viz
from sklearn.model_selection import RandomizedSearchCV
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras import activations

# %% [markdown]
# I will now load the dataset taken from the UCI machine learning repository. The SUSY Data Set consist in 5000000 instances with events of type signal and background. The attributes of each events are 18: 8 of low-level and 10 of high. The high level ones have been added and computed (as a function of the low-level ones) in order to see if their presence can help the performance of the algorithms chosen to study the problem.

# %%
names=["class label", "lepton 1 pT", "lepton 1 eta", "lepton 1 phi",
                     "lepton 2 pT", "lepton 2 eta", "lepton 2 phi",
                     "missing energy magnitude", "missing energy phi", 
                     "MET_rel", "axial MET","M_R", "M_TR_2", "R", "MT2", "S_R",
                     "M_Delta_R", "dPhi_r_b", "cos(theta_r1)"]
df = pd.read_csv('SUSY.csv', 
                 encoding='utf-8', 
                 comment='#',
                 sep=',',
                 names=names)
df.head(10)
# Out:
#    class label  lepton 1 pT  lepton 1 eta  lepton 1 phi  lepton 2 pT  \
# 0          0.0     0.972861      0.653855      1.176225     1.157156
# 1          1.0     1.667973      0.064191     -1.225171     0.506102
# 2          1.0     0.444840     -0.134298     -0.709972     0.451719
# 3          1.0     0.381256     -0.976145      0.693152     0.448959
# 4          1.0     1.309996     -0.690089     -0.676259     1.589283
# 5          0.0     0.456398      1.099371      1.512453     0.751772
# 6          0.0     0.437818     -1.119883     -1.336823     0.502320
# 7          0.0     0.571656      0.205696      0.425950     0.578514
# 8          1.0     2.112812      0.742983     -0.330539     0.805253
# 9          0.0     1.001869     -0.471788      0.555614     1.233368
#
#    lepton 2 eta  lepton 2 phi  missing energy magnitude  missing energy phi  \
# 0     -1.739873     -0.874309                  0.567765           -0.175000
# 1     -0.338939      1.672543                  3.475464           -1.219136
# 2     -1.613871     -0.768661                  1.219918            0.504026
# 3      0.891753     -0.677328                  2.033060            1.533041
# 4     -0.693326      0.622907                  1.087562           -0.381742
# 5      0.638967     -0.742216                  0.322601            1.321054
# 6     -1.717515      1.017067                  0.215619           -0.461200
# 7      0.927399     -1.101478                  0.116555            1.549753
# 8     -0.028887     -1.446679                  2.299946            1.450429
# 9      1.255548     -1.052491                  0.437615           -1.333052
#
#     MET_rel  axial MET       M_R    M_TR_2         R       MT2       S_R  \
# 0  0.810061  -0.252552  1.921887  0.889637  0.410772  1.145621  1.932632
# 1  0.012955   3.775174  1.045977  0.568051  0.481928  0.000000  0.448410
# 2  1.831248  -0.431385  0.526283  0.941514  1.587535  2.024308  0.603498
# 3  3.046260  -1.005285  0.569386  1.015211  1.582217  1.551914  0.761215
# 4  0.589204   1.365479  1.179295  0.968218  0.728563  0.000000  1.083158
# 5  0.169502   0.359941  0.489256  0.416168  0.754829  0.303750  0.461067
# 6  0.323671   0.173626  0.411898  0.370525  0.798260  0.671369  0.385910
# 7  0.174421   0.223450  0.523164  0.289889  0.491710  0.334593  0.514246
# 8  2.989110  -1.894770  1.445125  2.548166  1.564721  2.393632  1.554566
# 9  0.326858  -0.111678  1.435708  0.755201  0.466779  0.454541  1.446331
#
#    M_Delta_R  dPhi_r_b  cos(theta_r1)
# 0   0.994464  1.367815       0.040714
# 1   0.205356  1.321893       0.377584
# 2   1.562374  1.135454       0.180910
# 3   1.715464  1.492257       0.090719
# 4   0.043429  1.154854       0.094859
# 5   0.345541  0.733242       0.186044
# 6   0.515522  0.479110       0.029058
# 7   0.268207  0.315795       0.125728
# 8   2.148468  1.179117       0.688057
# 9   0.592259  1.325197       0.083014

# %% [markdown]
# I study three different models, in order to see to what extent the high-level features add useful information: one with just low-level features (first 8), another with just high-level ones (last 10) and a third one with both of them.
# Hence now i'll define the arrays.

# %%
#All features
x=df.iloc[:,1:]
x = x.values


#target
y = df["class label"].values

# %% [markdown]
# Below low-level variable are plotted. Those show some of the most distinguishing characteristic of the events.

# %%
fig, axL = plt.subplots(4,2, figsize=(10,23))
axL[0,0].hist(x[:,1][y==0], density=True,histtype='step', bins=70, label='Background')
axL[0,0].hist(x[:,1][y==1], density=True,histtype='step', bins=70, label='Signal')
axL[0,0].set_title("pT1 sig and bkg", fontsize = 16, color = 'black', alpha = .5)                        
axL[0,0].set_xlabel('pT',  fontsize = 16, color = 'black', alpha = 1)


axL[0,1].hist(x[:,2][y==0], density=True,histtype='step', bins=70, label='Background')
axL[0,1].hist(x[:,2][y==1], density=True,histtype='step', bins=70, label='Signal')
axL[0,1].set_title("eta1 sig and bkg", fontsize = 16, color = 'black', alpha = .5)                        
axL[0,1].set_xlabel('eta',  fontsize = 16, color = 'black', alpha = 1)

axL[1,0].hist(x[:,3][y==0], density=True,histtype='step', bins=70, label='Background')
axL[1,0].hist(x[:,3][y==1], density=True,histtype='step', bins=70, label='Signal')
axL[1,0].set_title("phi1 sig and bkg", fontsize = 16, color = 'black', alpha = .5)                        
axL[1,0].set_xlabel('phi',  fontsize = 16, color = 'black', alpha = 1)

axL[1,1].hist(x[:,4][y==0], density=True,histtype='step', bins=70, label='Background')
axL[1,1].hist(x[:,4][y==1], density=True,histtype='step', bins=70, label='Signal')
axL[1,1].set_title("pT2 sig and bkg", fontsize = 16, color = 'black', alpha = .5)                        
axL[1,1].set_xlabel('pT',  fontsize = 16, color = 'black', alpha = 1)

axL[2,0].hist(x[:,5][y==0], density=True,histtype='step', bins=70, label='Background')
axL[2,0].hist(x[:,5][y==1], density=True,histtype='step', bins=70, label='Signal')
axL[2,0].set_title("eta2 sig and bkg", fontsize = 16, color = 'black', alpha = .5)                        
axL[2,0].set_xlabel('eta',  fontsize = 16, color = 'black', alpha = 1)


axL[2,1].hist(x[:,6][y==0], density=True,histtype='step', bins=70, label='Background')
axL[2,1].hist(x[:,6][y==1], density=True,histtype='step', bins=70, label='Signal')
axL[2,1].set_title("phi2 sig and bkg", fontsize = 16, color = 'black', alpha = .5)                        
axL[2,1].set_xlabel('phi',  fontsize = 16, color = 'black', alpha = 1)

axL[3,0].hist(x[:,7][y==0], density=True,histtype='step', bins=70, label='Background')
axL[3,0].hist(x[:,7][y==1], density=True,histtype='step', bins=70, label='Signal')
axL[3,0].set_title("missing energy magnitude sig and bkg", fontsize = 16, color = 'black', alpha = .5)                        
axL[3,0].set_xlabel('E',  fontsize = 16, color = 'black', alpha = 1)

axL[3,1].hist(x[:,8][y==0], density=True,histtype='step', bins=70, label='Background')
axL[3,1].hist(x[:,8][y==1], density=True,histtype='step', bins=70, label='Signal')
axL[3,1].set_title("missing energy phi sig and bkg", fontsize = 16, color = 'black', alpha = .5)                        
axL[3,1].set_xlabel('phi',  fontsize = 16, color = 'black', alpha = 1)

plt.suptitle('Distributions of  low-level variables', fontsize=25)
axL[0,0].legend()
axL[0,1].legend()
axL[1,0].legend()
axL[1,1].legend()
axL[2,0].legend()
axL[2,1].legend()
axL[3,0].legend()
axL[3,1].legend()



plt.show()

# %% [markdown]
# The alghortims which i want to test are a Boosted Decision Three and a Shallow Neural Network.
# I define the training set, the validation set and the test one; the validation set will be useful to control if the model is a good one or if it under/overfits.
#
# Scaling the dataset helps in regularize the models and in order to facilitate the comparison between them.

# %%
class_counts= df.groupby('class label').size()
print(class_counts)



#all
x_train, x_test, y_train, y_test = train_test_split(x,y,
                            test_size=0.4,
                             random_state=42,stratify=y)

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.35, random_state=42)

#Scale the dataset
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)
x_test = scaler.transform(x_test)


#low-level features
xL_train=x_train[:,:8]

xL_test=x_test[:,:8]

xL_val=x_val[:,:8]

#high-level features
xH_train=x_train[:,8:]

xH_test=x_test[:,8:]

xH_val=x_val[:,8:]
# Out:
# class label
# 0.0    2712173
# 1.0    2287827
# dtype: int64

# %% [markdown]
# The dataset is fairly balanced between signal and background events.

# %% [markdown]
# # 1) BDT with XGBoost

# %%
# I use xgboost to build up my model, hence i build two matrices for train and test.
dtrain = xgb.DMatrix(x_train,y_train)
dval = xgb.DMatrix(x_val,y_val)
dtest = xgb.DMatrix(x_test,y_test)

dtrainL = xgb.DMatrix(xL_train,y_train)
dvalL = xgb.DMatrix(xL_val,y_val)
dtestL = xgb.DMatrix(xL_test,y_test)

dtrainH = xgb.DMatrix(xH_train,y_train)
dvalH = xgb.DMatrix(xH_val,y_val)
dtestH = xgb.DMatrix(xH_test,y_test)

# %% [markdown]
# I need to find the best parameters in order to have the best model which minimize the error. To do that i perform cross validation trying different values of parameters in selected ranges. All the hyper-parameter tuning methods were done considering the dataset with all the features, both for BDT and NN. Then the train is made separately on the three different sets.
#
# I start searching for max_depth, min_child_weight which helps in fixing the complexity and controlling overfit of the model. I'll consider the dataset with all the variables.

# %%
param = { }
param['objective'] ='binary:logistic' #good for classification
param['eval_metric'] = "error"
num_round = 70

gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(8,11) # i saw that 15 makes it to overfit, after some rounds the error starts to increase
    for min_child_weight in range(6,8)
]
# Define initial best params and error
min_err = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:
    print("CV with max_depth={}, min_child_weight={}".format(
                             max_depth,
                             min_child_weight))
# Update our parameters
    param['max_depth'] = max_depth
    param['min_child_weight'] = min_child_weight
# Run CV
    cv_results = xgb.cv(
        param,
        dtrain,
        num_boost_round=num_round,
        seed=42,
        nfold=3, # 5 was too long, choose this beacause the sample is large and it takes too much time
        metrics={'error'},
        early_stopping_rounds=6
    )
# Update best error
    mean_err = cv_results['test-error-mean'].min()
    boost_rounds = cv_results['test-error-mean'].argmin()
    print("\tError: {} for {} rounds".format(mean_err, boost_rounds))
    if mean_err < min_err:
        min_err = mean_err
        best_params = (max_depth,min_child_weight)
print("Best params: {}, {}, Error: {}".format(best_params[0], best_params[1], min_err))

# %% [markdown]
# CV with max_depth=8, min_child_weight=6
#
#         Error: 0.19779233333333335 for 41 rounds
#
# CV with max_depth=8, min_child_weight=7
#
#         Error: 0.19782666666666668 for 37 rounds
#
# CV with max_depth=9, min_child_weight=6
#
#         Error: 0.19779233333333335 for 31 rounds
#
# CV with max_depth=9, min_child_weight=7
#
#         Error: 0.19772333333333333 for 46 rounds
#
# CV with max_depth=10, min_child_weight=6
#
#         Error: 0.19784933333333332 for 28 rounds
#
# CV with max_depth=10, min_child_weight=7
#
#         Error: 0.197859 for 37 rounds
#
# Best params: 9, 7, Error: 0.19772333333333333

# %% [markdown]
# Hence i save these best parmeters and with another cross validation i find the best learning rate:

# %%
min_err = float("Inf")
best_params = None

for eta in [.3, .2, .1, .05]:
    print("CV with eta={}".format(eta))
    # We update our parameters
    param={}
    param['max_depth'] = 9
    param['min_child_weight'] = 6
    param['eta'] = eta
    # Run and time CV
    cv_results = xgb.cv(
            param,
            dtrain,
            num_boost_round=70,
            seed=42,
            nfold=3,
            metrics=['error'],
            early_stopping_rounds=6
          )
    # Update best score
    mean_err = cv_results['test-error-mean'].min()
    boost_rounds = cv_results['test-error-mean'].argmin()
    print("\tError {} for {} rounds\n".format(mean_err, boost_rounds))
    if mean_err < min_err:
        min_err = mean_err
        best_params = eta
print("Best params: {}, MAE: {}".format(best_params, min_err))

# %% [markdown]
# CV with eta=0.3
#
#         Error 0.19779233333333335 for 31 rounds
#
# CV with eta=0.2
#
#         Error 0.19726033333333334 for 61 rounds
#
# CV with eta=0.1
#
#         Error 0.19706733333333334 for 68 rounds
#
# CV with eta=0.05
#
#         Error 0.19823266666666664 for 69 rounds
#
# Best params: 0.1, Error: 0.19706733333333334

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Now that i have found the best parameters, i complete the study of my model with a final CV wth all the parameters chosen, using th validation set.
# I select now as a metric the AUC as is a good choice for classification problems and it is the one that i will use to compare the BDT and the NN alghoritms.

# %%
param = {'max_depth': 9, 'eta': 0.1, "min_child_weight": 7}
param['objective'] ='binary:logistic' 
param['eval_metric'] = "auc" 
num_round = 70 
# Run CV
cv_final = xgb.cv(
        param,
        dval,
        num_boost_round=num_round,
        seed=42,
        nfold=3, # 5 was too long, choose this beacause the sample is large and it takes less time
        metrics={'auc'},
        early_stopping_rounds=6
    )
print(cv_final)
# Out:
#     train-auc-mean  train-auc-std  test-auc-mean  test-auc-std
# 0         0.861968       0.000561       0.856009      0.000321
# 1         0.866549       0.000713       0.860416      0.000274
# 2         0.869169       0.000543       0.862758      0.000340
# 3         0.870593       0.000320       0.864037      0.000475
# 4         0.871879       0.000311       0.865005      0.000575
# ..             ...            ...            ...           ...
# 65        0.890143       0.000083       0.875067      0.000349
# 66        0.890226       0.000095       0.875072      0.000348
# 67        0.890349       0.000041       0.875076      0.000338
# 68        0.890483       0.000063       0.875088      0.000323
# 69        0.890628       0.000132       0.875101      0.000310
#
# [70 rows x 4 columns]

# %% [markdown]
# I have now the best model for the BDT considering all the variables, hence i can train and test it. I use early stopping to control the number of trees and avoid overfitting.

# %%
evallist = [(dval, 'eval'), (dtrain, 'train')]
param = [('max_depth', 9), ('eta', 0.1) , ("min_child_weight", 7),('eval_metric', "auc"), ('eval_metric', "logloss"), ('objective', 'binary:logistic')]
progress = dict()
num_round = 150 #low eta means larger num_round
bst = xgb.train(param, dtrain, num_round, evallist, early_stopping_rounds=6, evals_result=progress)
# Out:
# [0]	eval-auc:0.85814	eval-logloss:0.65439	train-auc:0.85925	train-logloss:0.65421
# Multiple eval metrics have been passed: 'train-logloss' will be used for early stopping.
#
# Will train until train-logloss hasn't improved in 6 rounds.
# [1]	eval-auc:0.86192	eval-logloss:0.62215	train-auc:0.86311	train-logloss:0.62194
# [2]	eval-auc:0.86369	eval-logloss:0.59552	train-auc:0.86496	train-logloss:0.59505
# [3]	eval-auc:0.86469	eval-logloss:0.57326	train-auc:0.86594	train-logloss:0.57268
# [4]	eval-auc:0.86559	eval-logloss:0.55428	train-auc:0.86688	train-logloss:0.55353
# [5]	eval-auc:0.86642	eval-logloss:0.53800	train-auc:0.86775	train-logloss:0.53704
# [6]	eval-auc:0.86713	eval-logloss:0.52438	train-auc:0.86849	train-logloss:0.52332
# [7]	eval-auc:0.86779	eval-logloss:0.51237	train-auc:0.86920	train-logloss:0.51116
# [8]	eval-auc:0.86829	eval-logloss:0.50202	train-auc:0.86974	train-logloss:0.50068
# [9]	eval-auc:0.86871	eval-logloss:0.49320	train-auc:0.87020	train-logloss:0.49184
# [10]	eval-auc:0.86918	eval-logloss:0.48554	train-auc:0.87072	train-logloss:0.48389
# [11]	eval-auc:0.86956	eval-logloss:0.47884	train-auc:0.87114	train-logloss:0.47706
# [12]	eval-auc:0.86989	eval-logloss:0.47306	train-auc:0.87152	train-logloss:0.47112
# [13]	eval-auc:0.87018	eval-logloss:0.46796	train-auc:0.87188	train-logloss:0.46590
# [14]	eval-auc:0.87062	eval-logloss:0.46352	train-auc:0.87236	train-logloss:0.46137
# [15]	eval-auc:0.87092	eval-logloss:0.45962	train-auc:0.87270	train-logloss:0.45749
# [16]	eval-auc:0.87128	eval-logloss:0.45608	train-auc:0.87311	train-logloss:0.45368
# [17]	eval-auc:0.87159	eval-logloss:0.45301	train-auc:0.87346	train-logloss:0.45052
# [18]	eval-auc:0.87193	eval-logloss:0.45026	train-auc:0.87385	train-logloss:0.44767
# [19]	eval-auc:0.87225	eval-logloss:0.44782	train-auc:0.87421	train-logloss:0.44508
# [20]	eval-auc:0.87246	eval-logloss:0.44575	train-auc:0.87447	train-logloss:0.44289
# [21]	eval-auc:0.87267	eval-logloss:0.44382	train-auc:0.87474	train-logloss:0.44098
# [22]	eval-auc:0.87292	eval-logloss:0.44211	train-auc:0.87503	train-logloss:0.43896
# [23]	eval-auc:0.87322	eval-logloss:0.44059	train-auc:0.87538	train-logloss:0.43737
# [24]	eval-auc:0.87343	eval-logloss:0.43926	train-auc:0.87566	train-logloss:0.43603
# [25]	eval-auc:0.87366	eval-logloss:0.43804	train-auc:0.87594	train-logloss:0.43457
# [26]	eval-auc:0.87381	eval-logloss:0.43697	train-auc:0.87613	train-logloss:0.43337
# [27]	eval-auc:0.87399	eval-logloss:0.43599	train-auc:0.87634	train-logloss:0.43232
# [28]	eval-auc:0.87412	eval-logloss:0.43523	train-auc:0.87652	train-logloss:0.43152
# [29]	eval-auc:0.87421	eval-logloss:0.43443	train-auc:0.87666	train-logloss:0.43072
# [30]	eval-auc:0.87431	eval-logloss:0.43382	train-auc:0.87680	train-logloss:0.42985
# [31]	eval-auc:0.87449	eval-logloss:0.43316	train-auc:0.87702	train-logloss:0.42904
# [32]	eval-auc:0.87461	eval-logloss:0.43256	train-auc:0.87719	train-logloss:0.42835
# [33]	eval-auc:0.87479	eval-logloss:0.43195	train-auc:0.87741	train-logloss:0.42766
# [34]	eval-auc:0.87493	eval-logloss:0.43144	train-auc:0.87759	train-logloss:0.42705
# [35]	eval-auc:0.87505	eval-logloss:0.43101	train-auc:0.87776	train-logloss:0.42655
# [36]	eval-auc:0.87514	eval-logloss:0.43064	train-auc:0.87792	train-logloss:0.42610
# [37]	eval-auc:0.87523	eval-logloss:0.43024	train-auc:0.87804	train-logloss:0.42566
# [38]	eval-auc:0.87535	eval-logloss:0.42985	train-auc:0.87819	train-logloss:0.42520
# [39]	eval-auc:0.87541	eval-logloss:0.42957	train-auc:0.87829	train-logloss:0.42486
# [40]	eval-auc:0.87549	eval-logloss:0.42928	train-auc:0.87841	train-logloss:0.42450
# [41]	eval-auc:0.87556	eval-logloss:0.42907	train-auc:0.87854	train-logloss:0.42405
# [42]	eval-auc:0.87561	eval-logloss:0.42889	train-auc:0.87865	train-logloss:0.42374
# [43]	eval-auc:0.87570	eval-logloss:0.42866	train-auc:0.87876	train-logloss:0.42342
# [44]	eval-auc:0.87573	eval-logloss:0.42850	train-auc:0.87882	train-logloss:0.42319
# [45]	eval-auc:0.87577	eval-logloss:0.42836	train-auc:0.87889	train-logloss:0.42297
# [46]	eval-auc:0.87586	eval-logloss:0.42815	train-auc:0.87900	train-logloss:0.42269
# [47]	eval-auc:0.87589	eval-logloss:0.42805	train-auc:0.87908	train-logloss:0.42250
# [48]	eval-auc:0.87598	eval-logloss:0.42781	train-auc:0.87921	train-logloss:0.42219
# [49]	eval-auc:0.87601	eval-logloss:0.42769	train-auc:0.87929	train-logloss:0.42200
# [50]	eval-auc:0.87611	eval-logloss:0.42748	train-auc:0.87943	train-logloss:0.42170
# [51]	eval-auc:0.87614	eval-logloss:0.42738	train-auc:0.87949	train-logloss:0.42155
# [52]	eval-auc:0.87617	eval-logloss:0.42729	train-auc:0.87956	train-logloss:0.42139
# [53]	eval-auc:0.87619	eval-logloss:0.42720	train-auc:0.87963	train-logloss:0.42123
# [54]	eval-auc:0.87621	eval-logloss:0.42714	train-auc:0.87967	train-logloss:0.42111
# [55]	eval-auc:0.87622	eval-logloss:0.42710	train-auc:0.87972	train-logloss:0.42100
# [56]	eval-auc:0.87627	eval-logloss:0.42697	train-auc:0.87980	train-logloss:0.42081
# [57]	eval-auc:0.87630	eval-logloss:0.42689	train-auc:0.87987	train-logloss:0.42065
# [58]	eval-auc:0.87631	eval-logloss:0.42685	train-auc:0.87992	train-logloss:0.42055
# [59]	eval-auc:0.87637	eval-logloss:0.42674	train-auc:0.88003	train-logloss:0.42035
# [60]	eval-auc:0.87639	eval-logloss:0.42670	train-auc:0.88010	train-logloss:0.42022
# [61]	eval-auc:0.87640	eval-logloss:0.42666	train-auc:0.88015	train-logloss:0.42012
# [62]	eval-auc:0.87645	eval-logloss:0.42656	train-auc:0.88025	train-logloss:0.41992
# [63]	eval-auc:0.87646	eval-logloss:0.42653	train-auc:0.88030	train-logloss:0.41982
# [64]	eval-auc:0.87652	eval-logloss:0.42642	train-auc:0.88042	train-logloss:0.41960
# [65]	eval-auc:0.87656	eval-logloss:0.42634	train-auc:0.88053	train-logloss:0.41939
# [66]	eval-auc:0.87656	eval-logloss:0.42632	train-auc:0.88056	train-logloss:0.41933
# [67]	eval-auc:0.87660	eval-logloss:0.42625	train-auc:0.88063	train-logloss:0.41921
# [68]	eval-auc:0.87660	eval-logloss:0.42623	train-auc:0.88069	train-logloss:0.41910
# [69]	eval-auc:0.87661	eval-logloss:0.42622	train-auc:0.88075	train-logloss:0.41900
# [70]	eval-auc:0.87666	eval-logloss:0.42612	train-auc:0.88089	train-logloss:0.41878
# [71]	eval-auc:0.87669	eval-logloss:0.42607	train-auc:0.88099	train-logloss:0.41860
# [72]	eval-auc:0.87670	eval-logloss:0.42604	train-auc:0.88102	train-logloss:0.41853
# [73]	eval-auc:0.87671	eval-logloss:0.42602	train-auc:0.88108	train-logloss:0.41843
# [74]	eval-auc:0.87673	eval-logloss:0.42598	train-auc:0.88113	train-logloss:0.41834
# [75]	eval-auc:0.87677	eval-logloss:0.42591	train-auc:0.88122	train-logloss:0.41815
# [76]	eval-auc:0.87678	eval-logloss:0.42588	train-auc:0.88129	train-logloss:0.41803
# [77]	eval-auc:0.87680	eval-logloss:0.42583	train-auc:0.88136	train-logloss:0.41790
# [78]	eval-auc:0.87682	eval-logloss:0.42580	train-auc:0.88145	train-logloss:0.41776
# [79]	eval-auc:0.87683	eval-logloss:0.42578	train-auc:0.88149	train-logloss:0.41767
# [80]	eval-auc:0.87683	eval-logloss:0.42577	train-auc:0.88154	train-logloss:0.41759
# [81]	eval-auc:0.87684	eval-logloss:0.42576	train-auc:0.88158	train-logloss:0.41752
# [82]	eval-auc:0.87684	eval-logloss:0.42574	train-auc:0.88160	train-logloss:0.41747
# [83]	eval-auc:0.87686	eval-logloss:0.42572	train-auc:0.88165	train-logloss:0.41737
# [84]	eval-auc:0.87686	eval-logloss:0.42571	train-auc:0.88168	train-logloss:0.41732
# [85]	eval-auc:0.87687	eval-logloss:0.42569	train-auc:0.88177	train-logloss:0.41717
# [86]	eval-auc:0.87688	eval-logloss:0.42567	train-auc:0.88183	train-logloss:0.41708
# [87]	eval-auc:0.87689	eval-logloss:0.42565	train-auc:0.88189	train-logloss:0.41697
# [88]	eval-auc:0.87689	eval-logloss:0.42564	train-auc:0.88192	train-logloss:0.41691
# [89]	eval-auc:0.87689	eval-logloss:0.42564	train-auc:0.88193	train-logloss:0.41688
# [90]	eval-auc:0.87689	eval-logloss:0.42563	train-auc:0.88195	train-logloss:0.41684
# [91]	eval-auc:0.87690	eval-logloss:0.42562	train-auc:0.88202	train-logloss:0.41674
# [92]	eval-auc:0.87690	eval-logloss:0.42562	train-auc:0.88207	train-logloss:0.41667
# [93]	eval-auc:0.87690	eval-logloss:0.42562	train-auc:0.88209	train-logloss:0.41664
# [94]	eval-auc:0.87690	eval-logloss:0.42561	train-auc:0.88213	train-logloss:0.41658
# [95]	eval-auc:0.87690	eval-logloss:0.42560	train-auc:0.88217	train-logloss:0.41651
# [96]	eval-auc:0.87690	eval-logloss:0.42560	train-auc:0.88220	train-logloss:0.41646
# [97]	eval-auc:0.87690	eval-logloss:0.42560	train-auc:0.88222	train-logloss:0.41643
# [98]	eval-auc:0.87690	eval-logloss:0.42560	train-auc:0.88225	train-logloss:0.41638
# [99]	eval-auc:0.87690	eval-logloss:0.42560	train-auc:0.88227	train-logloss:0.41636
# [100]	eval-auc:0.87691	eval-logloss:0.42559	train-auc:0.88230	train-logloss:0.41630
# [101]	eval-auc:0.87690	eval-logloss:0.42559	train-auc:0.88235	train-logloss:0.41623
# [102]	eval-auc:0.87690	eval-logloss:0.42559	train-auc:0.88237	train-logloss:0.41621
# [103]	eval-auc:0.87691	eval-logloss:0.42558	train-auc:0.88245	train-logloss:0.41609
# [104]	eval-auc:0.87692	eval-logloss:0.42556	train-auc:0.88249	train-logloss:0.41602
# [105]	eval-auc:0.87692	eval-logloss:0.42556	train-auc:0.88252	train-logloss:0.41595
# [106]	eval-auc:0.87692	eval-logloss:0.42556	train-auc:0.88253	train-logloss:0.41594
# [107]	eval-auc:0.87692	eval-logloss:0.42555	train-auc:0.88257	train-logloss:0.41588
# [108]	eval-auc:0.87693	eval-logloss:0.42554	train-auc:0.88260	train-logloss:0.41583
# [109]	eval-auc:0.87693	eval-logloss:0.42553	train-auc:0.88261	train-logloss:0.41580
# [110]	eval-auc:0.87693	eval-logloss:0.42553	train-auc:0.88264	train-logloss:0.41576
# [111]	eval-auc:0.87693	eval-logloss:0.42553	train-auc:0.88266	train-logloss:0.41573
# [112]	eval-auc:0.87693	eval-logloss:0.42552	train-auc:0.88267	train-logloss:0.41572
# [113]	eval-auc:0.87693	eval-logloss:0.42552	train-auc:0.88270	train-logloss:0.41568
# [114]	eval-auc:0.87696	eval-logloss:0.42548	train-auc:0.88278	train-logloss:0.41555
# [115]	eval-auc:0.87696	eval-logloss:0.42548	train-auc:0.88283	train-logloss:0.41547
# [116]	eval-auc:0.87696	eval-logloss:0.42547	train-auc:0.88285	train-logloss:0.41543
# [117]	eval-auc:0.87696	eval-logloss:0.42547	train-auc:0.88287	train-logloss:0.41540
# [118]	eval-auc:0.87698	eval-logloss:0.42545	train-auc:0.88296	train-logloss:0.41528
# [119]	eval-auc:0.87697	eval-logloss:0.42545	train-auc:0.88296	train-logloss:0.41527
# [120]	eval-auc:0.87697	eval-logloss:0.42545	train-auc:0.88299	train-logloss:0.41523
# [121]	eval-auc:0.87697	eval-logloss:0.42546	train-auc:0.88301	train-logloss:0.41520
# [122]	eval-auc:0.87699	eval-logloss:0.42544	train-auc:0.88307	train-logloss:0.41511
# [123]	eval-auc:0.87698	eval-logloss:0.42544	train-auc:0.88312	train-logloss:0.41505
# [124]	eval-auc:0.87698	eval-logloss:0.42544	train-auc:0.88315	train-logloss:0.41500
# [125]	eval-auc:0.87701	eval-logloss:0.42540	train-auc:0.88322	train-logloss:0.41489
# [126]	eval-auc:0.87702	eval-logloss:0.42538	train-auc:0.88329	train-logloss:0.41475
# [127]	eval-auc:0.87702	eval-logloss:0.42537	train-auc:0.88331	train-logloss:0.41471
# [128]	eval-auc:0.87702	eval-logloss:0.42537	train-auc:0.88332	train-logloss:0.41467
# [129]	eval-auc:0.87702	eval-logloss:0.42537	train-auc:0.88336	train-logloss:0.41461
# [130]	eval-auc:0.87703	eval-logloss:0.42535	train-auc:0.88342	train-logloss:0.41453
# [131]	eval-auc:0.87703	eval-logloss:0.42535	train-auc:0.88344	train-logloss:0.41451
# [132]	eval-auc:0.87703	eval-logloss:0.42535	train-auc:0.88344	train-logloss:0.41450
# [133]	eval-auc:0.87703	eval-logloss:0.42535	train-auc:0.88345	train-logloss:0.41448
# [134]	eval-auc:0.87703	eval-logloss:0.42535	train-auc:0.88346	train-logloss:0.41447
# [135]	eval-auc:0.87703	eval-logloss:0.42535	train-auc:0.88351	train-logloss:0.41440
# [136]	eval-auc:0.87702	eval-logloss:0.42536	train-auc:0.88354	train-logloss:0.41436
# [137]	eval-auc:0.87702	eval-logloss:0.42536	train-auc:0.88354	train-logloss:0.41435
# [138]	eval-auc:0.87703	eval-logloss:0.42535	train-auc:0.88359	train-logloss:0.41426
# [139]	eval-auc:0.87703	eval-logloss:0.42535	train-auc:0.88360	train-logloss:0.41424
# [140]	eval-auc:0.87703	eval-logloss:0.42534	train-auc:0.88362	train-logloss:0.41420
# [141]	eval-auc:0.87703	eval-logloss:0.42534	train-auc:0.88366	train-logloss:0.41414
# [142]	eval-auc:0.87703	eval-logloss:0.42534	train-auc:0.88367	train-logloss:0.41413
# [143]	eval-auc:0.87703	eval-logloss:0.42534	train-auc:0.88369	train-logloss:0.41409
# [144]	eval-auc:0.87705	eval-logloss:0.42532	train-auc:0.88378	train-logloss:0.41396
# [145]	eval-auc:0.87705	eval-logloss:0.42531	train-auc:0.88382	train-logloss:0.41389
# [146]	eval-auc:0.87705	eval-logloss:0.42531	train-auc:0.88385	train-logloss:0.41385
# [147]	eval-auc:0.87704	eval-logloss:0.42532	train-auc:0.88387	train-logloss:0.41382
# [148]	eval-auc:0.87704	eval-logloss:0.42532	train-auc:0.88388	train-logloss:0.41380
# [149]	eval-auc:0.87705	eval-logloss:0.42531	train-auc:0.88390	train-logloss:0.41377
# Best AUC: 0.414 with 150 rounds

# %%
y_pred = bst.predict(dtest)
print(roc_auc_score(y_test,y_pred))
results = progress
x_axis = range(0, 150)

# plot log loss
fig, ax = plt.subplots(figsize=(7,7))
ax.plot(x_axis, results['eval']['logloss'], label='Val')
ax.plot(x_axis, results['train']['logloss'], label='Train')
ax.legend()
plt.ylabel('Log Loss')
plt.title('XGBoost Log Loss')
plt.show()
# Out:
# 0.8767611700121801

# %% [markdown]
# Let's now mantein the same hyperparameters but on the low-features dataset and later on the high-features one. I want to see to what extent the third dataset add information which helps the algorithm in the learning step.

# %%
evallist = [(dvalL, 'eval'), (dtrainL, 'train')]
param = [('max_depth', 9), ('eta', 0.1) , ("min_child_weight", 7),('eval_metric', "auc"), ('eval_metric', "logloss"), ('objective', 'binary:logistic')]
progressL = dict()
num_round = 150 #low eta means larger num_round

bstL = xgb.train(param, dtrainL, num_round, evallist, early_stopping_rounds=6, evals_result=progressL)
# Out:
# [0]	eval-auc:0.85010	eval-logloss:0.65616	train-auc:0.85120	train-logloss:0.65599
# Multiple eval metrics have been passed: 'train-logloss' will be used for early stopping.
#
# Will train until train-logloss hasn't improved in 6 rounds.
# [1]	eval-auc:0.85222	eval-logloss:0.62587	train-auc:0.85331	train-logloss:0.62563
# [2]	eval-auc:0.85320	eval-logloss:0.60091	train-auc:0.85427	train-logloss:0.60055
# [3]	eval-auc:0.85388	eval-logloss:0.57996	train-auc:0.85494	train-logloss:0.57961
# [4]	eval-auc:0.85444	eval-logloss:0.56227	train-auc:0.85555	train-logloss:0.56170
# [5]	eval-auc:0.85484	eval-logloss:0.54740	train-auc:0.85600	train-logloss:0.54667
# [6]	eval-auc:0.85514	eval-logloss:0.53468	train-auc:0.85632	train-logloss:0.53385
# [7]	eval-auc:0.85541	eval-logloss:0.52389	train-auc:0.85664	train-logloss:0.52294
# [8]	eval-auc:0.85572	eval-logloss:0.51448	train-auc:0.85697	train-logloss:0.51344
# [9]	eval-auc:0.85594	eval-logloss:0.50656	train-auc:0.85723	train-logloss:0.50558
# [10]	eval-auc:0.85610	eval-logloss:0.49991	train-auc:0.85744	train-logloss:0.49851
# [11]	eval-auc:0.85630	eval-logloss:0.49391	train-auc:0.85768	train-logloss:0.49250
# [12]	eval-auc:0.85647	eval-logloss:0.48888	train-auc:0.85788	train-logloss:0.48735
# [13]	eval-auc:0.85667	eval-logloss:0.48444	train-auc:0.85810	train-logloss:0.48287
# [14]	eval-auc:0.85684	eval-logloss:0.48071	train-auc:0.85833	train-logloss:0.47897
# [15]	eval-auc:0.85701	eval-logloss:0.47734	train-auc:0.85852	train-logloss:0.47570
# [16]	eval-auc:0.85718	eval-logloss:0.47448	train-auc:0.85871	train-logloss:0.47263
# [17]	eval-auc:0.85730	eval-logloss:0.47203	train-auc:0.85887	train-logloss:0.47000
# [18]	eval-auc:0.85743	eval-logloss:0.46987	train-auc:0.85902	train-logloss:0.46786
# [19]	eval-auc:0.85754	eval-logloss:0.46797	train-auc:0.85917	train-logloss:0.46579
# [20]	eval-auc:0.85769	eval-logloss:0.46627	train-auc:0.85935	train-logloss:0.46404
# [21]	eval-auc:0.85778	eval-logloss:0.46480	train-auc:0.85947	train-logloss:0.46260
# [22]	eval-auc:0.85788	eval-logloss:0.46365	train-auc:0.85960	train-logloss:0.46116
# [23]	eval-auc:0.85798	eval-logloss:0.46248	train-auc:0.85973	train-logloss:0.45998
# [24]	eval-auc:0.85806	eval-logloss:0.46147	train-auc:0.85985	train-logloss:0.45899
# [25]	eval-auc:0.85813	eval-logloss:0.46068	train-auc:0.85995	train-logloss:0.45791
# [26]	eval-auc:0.85822	eval-logloss:0.45989	train-auc:0.86008	train-logloss:0.45705
# [27]	eval-auc:0.85831	eval-logloss:0.45923	train-auc:0.86021	train-logloss:0.45634
# [28]	eval-auc:0.85841	eval-logloss:0.45867	train-auc:0.86034	train-logloss:0.45574
# [29]	eval-auc:0.85846	eval-logloss:0.45808	train-auc:0.86042	train-logloss:0.45516
# [30]	eval-auc:0.85853	eval-logloss:0.45766	train-auc:0.86054	train-logloss:0.45452
# [31]	eval-auc:0.85860	eval-logloss:0.45728	train-auc:0.86065	train-logloss:0.45400
# [32]	eval-auc:0.85866	eval-logloss:0.45687	train-auc:0.86075	train-logloss:0.45353
# [33]	eval-auc:0.85872	eval-logloss:0.45654	train-auc:0.86084	train-logloss:0.45314
# [34]	eval-auc:0.85876	eval-logloss:0.45629	train-auc:0.86092	train-logloss:0.45282
# [35]	eval-auc:0.85880	eval-logloss:0.45608	train-auc:0.86099	train-logloss:0.45254
# [36]	eval-auc:0.85885	eval-logloss:0.45586	train-auc:0.86107	train-logloss:0.45227
# [37]	eval-auc:0.85889	eval-logloss:0.45562	train-auc:0.86112	train-logloss:0.45201
# [38]	eval-auc:0.85892	eval-logloss:0.45544	train-auc:0.86119	train-logloss:0.45180
# [39]	eval-auc:0.85896	eval-logloss:0.45526	train-auc:0.86128	train-logloss:0.45156
# [40]	eval-auc:0.85899	eval-logloss:0.45515	train-auc:0.86134	train-logloss:0.45138
# [41]	eval-auc:0.85903	eval-logloss:0.45502	train-auc:0.86141	train-logloss:0.45121
# [42]	eval-auc:0.85907	eval-logloss:0.45491	train-auc:0.86148	train-logloss:0.45087
# [43]	eval-auc:0.85908	eval-logloss:0.45483	train-auc:0.86152	train-logloss:0.45071
# [44]	eval-auc:0.85912	eval-logloss:0.45475	train-auc:0.86160	train-logloss:0.45054
# [45]	eval-auc:0.85918	eval-logloss:0.45458	train-auc:0.86169	train-logloss:0.45031
# [46]	eval-auc:0.85920	eval-logloss:0.45453	train-auc:0.86175	train-logloss:0.45018
# [47]	eval-auc:0.85921	eval-logloss:0.45446	train-auc:0.86181	train-logloss:0.45004
# [48]	eval-auc:0.85967	eval-logloss:0.45366	train-auc:0.86229	train-logloss:0.44917
# [49]	eval-auc:0.85977	eval-logloss:0.45343	train-auc:0.86241	train-logloss:0.44892
# [50]	eval-auc:0.85978	eval-logloss:0.45338	train-auc:0.86245	train-logloss:0.44881
# [51]	eval-auc:0.85979	eval-logloss:0.45334	train-auc:0.86249	train-logloss:0.44872
# [52]	eval-auc:0.85982	eval-logloss:0.45327	train-auc:0.86255	train-logloss:0.44860
# [53]	eval-auc:0.85982	eval-logloss:0.45325	train-auc:0.86257	train-logloss:0.44854
# [54]	eval-auc:0.85994	eval-logloss:0.45311	train-auc:0.86276	train-logloss:0.44830
# [55]	eval-auc:0.86001	eval-logloss:0.45300	train-auc:0.86286	train-logloss:0.44815
# [56]	eval-auc:0.86002	eval-logloss:0.45296	train-auc:0.86289	train-logloss:0.44808
# [57]	eval-auc:0.86007	eval-logloss:0.45289	train-auc:0.86297	train-logloss:0.44797
# [58]	eval-auc:0.86037	eval-logloss:0.45251	train-auc:0.86332	train-logloss:0.44752
# [59]	eval-auc:0.86041	eval-logloss:0.45246	train-auc:0.86339	train-logloss:0.44741
# [60]	eval-auc:0.86043	eval-logloss:0.45242	train-auc:0.86344	train-logloss:0.44732
# [61]	eval-auc:0.86043	eval-logloss:0.45241	train-auc:0.86346	train-logloss:0.44728
# [62]	eval-auc:0.86044	eval-logloss:0.45239	train-auc:0.86350	train-logloss:0.44719
# [63]	eval-auc:0.86046	eval-logloss:0.45235	train-auc:0.86356	train-logloss:0.44711
# [64]	eval-auc:0.86047	eval-logloss:0.45232	train-auc:0.86359	train-logloss:0.44704
# [65]	eval-auc:0.86049	eval-logloss:0.45229	train-auc:0.86364	train-logloss:0.44697
# [66]	eval-auc:0.86090	eval-logloss:0.45150	train-auc:0.86409	train-logloss:0.44612
# [67]	eval-auc:0.86099	eval-logloss:0.45138	train-auc:0.86419	train-logloss:0.44598
# [68]	eval-auc:0.86136	eval-logloss:0.45069	train-auc:0.86459	train-logloss:0.44523
# [69]	eval-auc:0.86136	eval-logloss:0.45068	train-auc:0.86461	train-logloss:0.44521
# [70]	eval-auc:0.86140	eval-logloss:0.45063	train-auc:0.86470	train-logloss:0.44509
# [71]	eval-auc:0.86142	eval-logloss:0.45061	train-auc:0.86473	train-logloss:0.44505
# [72]	eval-auc:0.86143	eval-logloss:0.45059	train-auc:0.86480	train-logloss:0.44497
# [73]	eval-auc:0.86158	eval-logloss:0.45036	train-auc:0.86498	train-logloss:0.44467
# [74]	eval-auc:0.86283	eval-logloss:0.44865	train-auc:0.86637	train-logloss:0.44281
# [75]	eval-auc:0.86332	eval-logloss:0.44795	train-auc:0.86689	train-logloss:0.44208
# [76]	eval-auc:0.86429	eval-logloss:0.44656	train-auc:0.86799	train-logloss:0.44054
# [77]	eval-auc:0.86497	eval-logloss:0.44557	train-auc:0.86879	train-logloss:0.43941
# [78]	eval-auc:0.86544	eval-logloss:0.44484	train-auc:0.86932	train-logloss:0.43860
# [79]	eval-auc:0.86573	eval-logloss:0.44442	train-auc:0.86964	train-logloss:0.43813
# [80]	eval-auc:0.86616	eval-logloss:0.44384	train-auc:0.87016	train-logloss:0.43745
# [81]	eval-auc:0.86656	eval-logloss:0.44321	train-auc:0.87060	train-logloss:0.43675
# [82]	eval-auc:0.86664	eval-logloss:0.44308	train-auc:0.87073	train-logloss:0.43654
# [83]	eval-auc:0.86707	eval-logloss:0.44243	train-auc:0.87125	train-logloss:0.43578
# [84]	eval-auc:0.86714	eval-logloss:0.44230	train-auc:0.87134	train-logloss:0.43561
# [85]	eval-auc:0.86714	eval-logloss:0.44229	train-auc:0.87138	train-logloss:0.43555
# [86]	eval-auc:0.86741	eval-logloss:0.44193	train-auc:0.87172	train-logloss:0.43509
# [87]	eval-auc:0.86763	eval-logloss:0.44155	train-auc:0.87198	train-logloss:0.43465
# [88]	eval-auc:0.86764	eval-logloss:0.44153	train-auc:0.87201	train-logloss:0.43460
# [89]	eval-auc:0.86785	eval-logloss:0.44121	train-auc:0.87228	train-logloss:0.43420
# [90]	eval-auc:0.86792	eval-logloss:0.44106	train-auc:0.87239	train-logloss:0.43401
# [91]	eval-auc:0.86816	eval-logloss:0.44068	train-auc:0.87270	train-logloss:0.43353
# [92]	eval-auc:0.86819	eval-logloss:0.44062	train-auc:0.87275	train-logloss:0.43343
# [93]	eval-auc:0.86840	eval-logloss:0.44028	train-auc:0.87303	train-logloss:0.43299
# [94]	eval-auc:0.86857	eval-logloss:0.43998	train-auc:0.87324	train-logloss:0.43262
# [95]	eval-auc:0.86880	eval-logloss:0.43958	train-auc:0.87354	train-logloss:0.43212
# [96]	eval-auc:0.86892	eval-logloss:0.43936	train-auc:0.87370	train-logloss:0.43183
# [97]	eval-auc:0.86910	eval-logloss:0.43906	train-auc:0.87394	train-logloss:0.43144
# [98]	eval-auc:0.86928	eval-logloss:0.43877	train-auc:0.87416	train-logloss:0.43108
# [99]	eval-auc:0.86942	eval-logloss:0.43854	train-auc:0.87435	train-logloss:0.43078
# [100]	eval-auc:0.86950	eval-logloss:0.43839	train-auc:0.87447	train-logloss:0.43058
# [101]	eval-auc:0.86956	eval-logloss:0.43829	train-auc:0.87458	train-logloss:0.43042
# [102]	eval-auc:0.86976	eval-logloss:0.43796	train-auc:0.87480	train-logloss:0.43004
# [103]	eval-auc:0.86980	eval-logloss:0.43789	train-auc:0.87490	train-logloss:0.42990
# [104]	eval-auc:0.86995	eval-logloss:0.43762	train-auc:0.87508	train-logloss:0.42958
# [105]	eval-auc:0.86998	eval-logloss:0.43757	train-auc:0.87513	train-logloss:0.42950
# [106]	eval-auc:0.86998	eval-logloss:0.43756	train-auc:0.87514	train-logloss:0.42947
# [107]	eval-auc:0.86998	eval-logloss:0.43756	train-auc:0.87517	train-logloss:0.42942
# [108]	eval-auc:0.87008	eval-logloss:0.43739	train-auc:0.87531	train-logloss:0.42918
# [109]	eval-auc:0.87007	eval-logloss:0.43738	train-auc:0.87534	train-logloss:0.42914
# [110]	eval-auc:0.87009	eval-logloss:0.43734	train-auc:0.87538	train-logloss:0.42906
# [111]	eval-auc:0.87009	eval-logloss:0.43734	train-auc:0.87541	train-logloss:0.42902
# [112]	eval-auc:0.87019	eval-logloss:0.43718	train-auc:0.87553	train-logloss:0.42882
# [113]	eval-auc:0.87019	eval-logloss:0.43717	train-auc:0.87555	train-logloss:0.42880
# [114]	eval-auc:0.87027	eval-logloss:0.43702	train-auc:0.87566	train-logloss:0.42860
# [115]	eval-auc:0.87027	eval-logloss:0.43702	train-auc:0.87569	train-logloss:0.42855
# [116]	eval-auc:0.87028	eval-logloss:0.43700	train-auc:0.87572	train-logloss:0.42850
# [117]	eval-auc:0.87028	eval-logloss:0.43700	train-auc:0.87574	train-logloss:0.42847
# [118]	eval-auc:0.87040	eval-logloss:0.43679	train-auc:0.87591	train-logloss:0.42819
# [119]	eval-auc:0.87050	eval-logloss:0.43660	train-auc:0.87605	train-logloss:0.42794
# [120]	eval-auc:0.87057	eval-logloss:0.43649	train-auc:0.87615	train-logloss:0.42778
# [121]	eval-auc:0.87057	eval-logloss:0.43648	train-auc:0.87616	train-logloss:0.42774
# [122]	eval-auc:0.87062	eval-logloss:0.43640	train-auc:0.87624	train-logloss:0.42762
# [123]	eval-auc:0.87069	eval-logloss:0.43628	train-auc:0.87634	train-logloss:0.42747
# [124]	eval-auc:0.87071	eval-logloss:0.43625	train-auc:0.87638	train-logloss:0.42740
# [125]	eval-auc:0.87082	eval-logloss:0.43607	train-auc:0.87652	train-logloss:0.42717
# [126]	eval-auc:0.87088	eval-logloss:0.43598	train-auc:0.87661	train-logloss:0.42701
# [127]	eval-auc:0.87092	eval-logloss:0.43591	train-auc:0.87667	train-logloss:0.42690
# [128]	eval-auc:0.87103	eval-logloss:0.43572	train-auc:0.87682	train-logloss:0.42665
# [129]	eval-auc:0.87105	eval-logloss:0.43567	train-auc:0.87688	train-logloss:0.42655
# [130]	eval-auc:0.87110	eval-logloss:0.43561	train-auc:0.87695	train-logloss:0.42643
# [131]	eval-auc:0.87109	eval-logloss:0.43560	train-auc:0.87697	train-logloss:0.42640
# [132]	eval-auc:0.87118	eval-logloss:0.43544	train-auc:0.87709	train-logloss:0.42618
# [133]	eval-auc:0.87118	eval-logloss:0.43544	train-auc:0.87711	train-logloss:0.42616
# [134]	eval-auc:0.87118	eval-logloss:0.43544	train-auc:0.87713	train-logloss:0.42613
# [135]	eval-auc:0.87120	eval-logloss:0.43542	train-auc:0.87718	train-logloss:0.42607
# [136]	eval-auc:0.87123	eval-logloss:0.43537	train-auc:0.87723	train-logloss:0.42599
# [137]	eval-auc:0.87123	eval-logloss:0.43537	train-auc:0.87727	train-logloss:0.42593
# [138]	eval-auc:0.87123	eval-logloss:0.43537	train-auc:0.87728	train-logloss:0.42591
# [139]	eval-auc:0.87133	eval-logloss:0.43517	train-auc:0.87743	train-logloss:0.42564
# [140]	eval-auc:0.87133	eval-logloss:0.43517	train-auc:0.87744	train-logloss:0.42562
# [141]	eval-auc:0.87134	eval-logloss:0.43516	train-auc:0.87748	train-logloss:0.42556
# [142]	eval-auc:0.87138	eval-logloss:0.43509	train-auc:0.87755	train-logloss:0.42545
# [143]	eval-auc:0.87140	eval-logloss:0.43505	train-auc:0.87758	train-logloss:0.42539
# [144]	eval-auc:0.87147	eval-logloss:0.43492	train-auc:0.87772	train-logloss:0.42516
# [145]	eval-auc:0.87148	eval-logloss:0.43491	train-auc:0.87774	train-logloss:0.42512
# [146]	eval-auc:0.87159	eval-logloss:0.43470	train-auc:0.87793	train-logloss:0.42479
# [147]	eval-auc:0.87163	eval-logloss:0.43462	train-auc:0.87801	train-logloss:0.42466
# [148]	eval-auc:0.87163	eval-logloss:0.43461	train-auc:0.87803	train-logloss:0.42462
# [149]	eval-auc:0.87163	eval-logloss:0.43461	train-auc:0.87804	train-logloss:0.42459
# Best AUC: 0.425 with 150 rounds

# %%
y_predL = bstL.predict(dtestL)
print(roc_auc_score(y_test,y_predL))

resultsL = progressL
x_axis = range(0, 150)

# plot log loss
fig, ax = plt.subplots(figsize=(7,7))
ax.plot(x_axis, resultsL['train']['logloss'], label='Train')
ax.plot(x_axis, resultsL['eval']['logloss'], label='Val')
ax.legend()
plt.ylabel('Log Loss')
plt.title('XGBoost Log Loss')
plt.show()
# Out:
# 0.8712020609043359
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-fc57e0e94662> in <module>
#       7 # plot log loss
#       8 fig, ax = plt.subplots(figsize=(7,7))
# ----> 9 ax.plot(x_axis, resultsL['train']['logloss'], label='Train')
#      10 ax.plot(x_axis, resultsL['eval']['logloss'], label='Val')
#      11 ax.legend()
#
# KeyError: 'train'

# %%
evallist = [(dvalH, 'eval'), (dtrainH, 'train')]
param = [('max_depth', 9), ('eta', 0.1) , ("min_child_weight", 7),('eval_metric', "auc"), ('eval_metric', "logloss"), ('objective', 'binary:logistic')]
progressH = dict()
num_round = 150 #low eta means larger num_round
bstH = xgb.train(param, dtrainH, num_round, evallist, early_stopping_rounds=6, evals_result=progressH)
# Out:
# [0]	eval-auc:0.84674	eval-logloss:0.65615	train-auc:0.84735	train-logloss:0.65588
# Multiple eval metrics have been passed: 'train-logloss' will be used for early stopping.
#
# Will train until train-logloss hasn't improved in 6 rounds.
# [1]	eval-auc:0.84991	eval-logloss:0.62580	train-auc:0.85048	train-logloss:0.62579
# [2]	eval-auc:0.85222	eval-logloss:0.60032	train-auc:0.85295	train-logloss:0.59981
# [3]	eval-auc:0.85368	eval-logloss:0.57904	train-auc:0.85443	train-logloss:0.57871
# [4]	eval-auc:0.85432	eval-logloss:0.56122	train-auc:0.85513	train-logloss:0.56059
# [5]	eval-auc:0.85513	eval-logloss:0.54593	train-auc:0.85596	train-logloss:0.54523
# [6]	eval-auc:0.85585	eval-logloss:0.53298	train-auc:0.85671	train-logloss:0.53220
# [7]	eval-auc:0.85649	eval-logloss:0.52178	train-auc:0.85737	train-logloss:0.52090
# [8]	eval-auc:0.85674	eval-logloss:0.51234	train-auc:0.85765	train-logloss:0.51124
# [9]	eval-auc:0.85719	eval-logloss:0.50413	train-auc:0.85812	train-logloss:0.50311
# [10]	eval-auc:0.85776	eval-logloss:0.49689	train-auc:0.85873	train-logloss:0.49565
# [11]	eval-auc:0.85821	eval-logloss:0.49069	train-auc:0.85922	train-logloss:0.48935
# [12]	eval-auc:0.85856	eval-logloss:0.48515	train-auc:0.85961	train-logloss:0.48371
# [13]	eval-auc:0.85893	eval-logloss:0.48053	train-auc:0.85999	train-logloss:0.47898
# [14]	eval-auc:0.85944	eval-logloss:0.47619	train-auc:0.86051	train-logloss:0.47462
# [15]	eval-auc:0.85963	eval-logloss:0.47260	train-auc:0.86075	train-logloss:0.47111
# [16]	eval-auc:0.85997	eval-logloss:0.46944	train-auc:0.86114	train-logloss:0.46769
# [17]	eval-auc:0.86041	eval-logloss:0.46657	train-auc:0.86163	train-logloss:0.46471
# [18]	eval-auc:0.86071	eval-logloss:0.46406	train-auc:0.86195	train-logloss:0.46216
# [19]	eval-auc:0.86094	eval-logloss:0.46189	train-auc:0.86221	train-logloss:0.45988
# [20]	eval-auc:0.86105	eval-logloss:0.46005	train-auc:0.86233	train-logloss:0.45800
# [21]	eval-auc:0.86137	eval-logloss:0.45827	train-auc:0.86267	train-logloss:0.45630
# [22]	eval-auc:0.86154	eval-logloss:0.45688	train-auc:0.86285	train-logloss:0.45461
# [23]	eval-auc:0.86177	eval-logloss:0.45550	train-auc:0.86311	train-logloss:0.45325
# [24]	eval-auc:0.86192	eval-logloss:0.45434	train-auc:0.86328	train-logloss:0.45213
# [25]	eval-auc:0.86213	eval-logloss:0.45328	train-auc:0.86352	train-logloss:0.45081
# [26]	eval-auc:0.86234	eval-logloss:0.45223	train-auc:0.86375	train-logloss:0.44971
# [27]	eval-auc:0.86247	eval-logloss:0.45145	train-auc:0.86391	train-logloss:0.44892
# [28]	eval-auc:0.86263	eval-logloss:0.45073	train-auc:0.86410	train-logloss:0.44817
# [29]	eval-auc:0.86277	eval-logloss:0.44997	train-auc:0.86427	train-logloss:0.44744
# [30]	eval-auc:0.86287	eval-logloss:0.44944	train-auc:0.86439	train-logloss:0.44670
# [31]	eval-auc:0.86304	eval-logloss:0.44884	train-auc:0.86459	train-logloss:0.44598
# [32]	eval-auc:0.86316	eval-logloss:0.44827	train-auc:0.86474	train-logloss:0.44538
# [33]	eval-auc:0.86325	eval-logloss:0.44784	train-auc:0.86484	train-logloss:0.44492
# [34]	eval-auc:0.86334	eval-logloss:0.44746	train-auc:0.86497	train-logloss:0.44449
# [35]	eval-auc:0.86344	eval-logloss:0.44714	train-auc:0.86510	train-logloss:0.44411
# [36]	eval-auc:0.86354	eval-logloss:0.44680	train-auc:0.86522	train-logloss:0.44374
# [37]	eval-auc:0.86360	eval-logloss:0.44650	train-auc:0.86530	train-logloss:0.44341
# [38]	eval-auc:0.86367	eval-logloss:0.44618	train-auc:0.86539	train-logloss:0.44307
# [39]	eval-auc:0.86374	eval-logloss:0.44593	train-auc:0.86547	train-logloss:0.44280
# [40]	eval-auc:0.86378	eval-logloss:0.44574	train-auc:0.86553	train-logloss:0.44260
# [41]	eval-auc:0.86386	eval-logloss:0.44552	train-auc:0.86564	train-logloss:0.44228
# [42]	eval-auc:0.86391	eval-logloss:0.44536	train-auc:0.86570	train-logloss:0.44192
# [43]	eval-auc:0.86395	eval-logloss:0.44523	train-auc:0.86575	train-logloss:0.44172
# [44]	eval-auc:0.86402	eval-logloss:0.44507	train-auc:0.86584	train-logloss:0.44151
# [45]	eval-auc:0.86406	eval-logloss:0.44491	train-auc:0.86589	train-logloss:0.44132
# [46]	eval-auc:0.86409	eval-logloss:0.44480	train-auc:0.86594	train-logloss:0.44118
# [47]	eval-auc:0.86416	eval-logloss:0.44466	train-auc:0.86603	train-logloss:0.44097
# [48]	eval-auc:0.86419	eval-logloss:0.44457	train-auc:0.86608	train-logloss:0.44083
# [49]	eval-auc:0.86422	eval-logloss:0.44441	train-auc:0.86613	train-logloss:0.44065
# [50]	eval-auc:0.86424	eval-logloss:0.44431	train-auc:0.86617	train-logloss:0.44051
# [51]	eval-auc:0.86427	eval-logloss:0.44423	train-auc:0.86621	train-logloss:0.44038
# [52]	eval-auc:0.86433	eval-logloss:0.44412	train-auc:0.86629	train-logloss:0.44023
# [53]	eval-auc:0.86435	eval-logloss:0.44406	train-auc:0.86632	train-logloss:0.44014
# [54]	eval-auc:0.86441	eval-logloss:0.44394	train-auc:0.86641	train-logloss:0.43997
# [55]	eval-auc:0.86443	eval-logloss:0.44388	train-auc:0.86644	train-logloss:0.43988
# [56]	eval-auc:0.86444	eval-logloss:0.44383	train-auc:0.86646	train-logloss:0.43980
# [57]	eval-auc:0.86447	eval-logloss:0.44377	train-auc:0.86650	train-logloss:0.43971
# [58]	eval-auc:0.86449	eval-logloss:0.44370	train-auc:0.86655	train-logloss:0.43960
# [59]	eval-auc:0.86451	eval-logloss:0.44366	train-auc:0.86657	train-logloss:0.43954
# [60]	eval-auc:0.86456	eval-logloss:0.44356	train-auc:0.86664	train-logloss:0.43939
# [61]	eval-auc:0.86461	eval-logloss:0.44346	train-auc:0.86673	train-logloss:0.43922
# [62]	eval-auc:0.86462	eval-logloss:0.44344	train-auc:0.86675	train-logloss:0.43917
# [63]	eval-auc:0.86465	eval-logloss:0.44338	train-auc:0.86679	train-logloss:0.43909
# [64]	eval-auc:0.86469	eval-logloss:0.44331	train-auc:0.86687	train-logloss:0.43895
# [65]	eval-auc:0.86472	eval-logloss:0.44324	train-auc:0.86694	train-logloss:0.43884
# [66]	eval-auc:0.86475	eval-logloss:0.44319	train-auc:0.86698	train-logloss:0.43875
# [67]	eval-auc:0.86476	eval-logloss:0.44316	train-auc:0.86700	train-logloss:0.43870
# [68]	eval-auc:0.86477	eval-logloss:0.44314	train-auc:0.86702	train-logloss:0.43865
# [69]	eval-auc:0.86482	eval-logloss:0.44307	train-auc:0.86710	train-logloss:0.43853
# [70]	eval-auc:0.86484	eval-logloss:0.44303	train-auc:0.86713	train-logloss:0.43848
# [71]	eval-auc:0.86486	eval-logloss:0.44300	train-auc:0.86717	train-logloss:0.43842
# [72]	eval-auc:0.86489	eval-logloss:0.44294	train-auc:0.86722	train-logloss:0.43832
# [73]	eval-auc:0.86491	eval-logloss:0.44290	train-auc:0.86726	train-logloss:0.43823
# [74]	eval-auc:0.86496	eval-logloss:0.44282	train-auc:0.86735	train-logloss:0.43808
# [75]	eval-auc:0.86496	eval-logloss:0.44281	train-auc:0.86736	train-logloss:0.43804
# [76]	eval-auc:0.86497	eval-logloss:0.44278	train-auc:0.86738	train-logloss:0.43800
# [77]	eval-auc:0.86501	eval-logloss:0.44272	train-auc:0.86745	train-logloss:0.43786
# [78]	eval-auc:0.86505	eval-logloss:0.44266	train-auc:0.86756	train-logloss:0.43773
# [79]	eval-auc:0.86507	eval-logloss:0.44262	train-auc:0.86762	train-logloss:0.43762
# [80]	eval-auc:0.86507	eval-logloss:0.44262	train-auc:0.86763	train-logloss:0.43761
# [81]	eval-auc:0.86511	eval-logloss:0.44256	train-auc:0.86770	train-logloss:0.43748
# [82]	eval-auc:0.86513	eval-logloss:0.44252	train-auc:0.86774	train-logloss:0.43741
# [83]	eval-auc:0.86518	eval-logloss:0.44245	train-auc:0.86786	train-logloss:0.43723
# [84]	eval-auc:0.86520	eval-logloss:0.44243	train-auc:0.86790	train-logloss:0.43718
# [85]	eval-auc:0.86520	eval-logloss:0.44242	train-auc:0.86791	train-logloss:0.43715
# [86]	eval-auc:0.86521	eval-logloss:0.44241	train-auc:0.86794	train-logloss:0.43711
# [87]	eval-auc:0.86523	eval-logloss:0.44238	train-auc:0.86799	train-logloss:0.43704
# [88]	eval-auc:0.86526	eval-logloss:0.44233	train-auc:0.86805	train-logloss:0.43694
# [89]	eval-auc:0.86527	eval-logloss:0.44232	train-auc:0.86807	train-logloss:0.43691
# [90]	eval-auc:0.86531	eval-logloss:0.44225	train-auc:0.86818	train-logloss:0.43672
# [91]	eval-auc:0.86536	eval-logloss:0.44217	train-auc:0.86829	train-logloss:0.43654
# [92]	eval-auc:0.86539	eval-logloss:0.44211	train-auc:0.86835	train-logloss:0.43642
# [93]	eval-auc:0.86540	eval-logloss:0.44210	train-auc:0.86840	train-logloss:0.43634
# [94]	eval-auc:0.86540	eval-logloss:0.44210	train-auc:0.86841	train-logloss:0.43632
# [95]	eval-auc:0.86540	eval-logloss:0.44208	train-auc:0.86843	train-logloss:0.43627
# [96]	eval-auc:0.86545	eval-logloss:0.44202	train-auc:0.86857	train-logloss:0.43608
# [97]	eval-auc:0.86547	eval-logloss:0.44198	train-auc:0.86865	train-logloss:0.43597
# [98]	eval-auc:0.86547	eval-logloss:0.44198	train-auc:0.86866	train-logloss:0.43594
# [99]	eval-auc:0.86548	eval-logloss:0.44195	train-auc:0.86869	train-logloss:0.43588
# [100]	eval-auc:0.86548	eval-logloss:0.44195	train-auc:0.86869	train-logloss:0.43586
# [101]	eval-auc:0.86548	eval-logloss:0.44195	train-auc:0.86870	train-logloss:0.43585
# [102]	eval-auc:0.86552	eval-logloss:0.44190	train-auc:0.86877	train-logloss:0.43576
# [103]	eval-auc:0.86553	eval-logloss:0.44189	train-auc:0.86881	train-logloss:0.43570
# [104]	eval-auc:0.86555	eval-logloss:0.44186	train-auc:0.86885	train-logloss:0.43561
# [105]	eval-auc:0.86555	eval-logloss:0.44185	train-auc:0.86889	train-logloss:0.43555
# [106]	eval-auc:0.86560	eval-logloss:0.44178	train-auc:0.86905	train-logloss:0.43534
# [107]	eval-auc:0.86560	eval-logloss:0.44177	train-auc:0.86906	train-logloss:0.43532
# [108]	eval-auc:0.86560	eval-logloss:0.44177	train-auc:0.86908	train-logloss:0.43529
# [109]	eval-auc:0.86560	eval-logloss:0.44177	train-auc:0.86908	train-logloss:0.43527
# [110]	eval-auc:0.86562	eval-logloss:0.44175	train-auc:0.86916	train-logloss:0.43518
# [111]	eval-auc:0.86565	eval-logloss:0.44171	train-auc:0.86930	train-logloss:0.43500
# [112]	eval-auc:0.86568	eval-logloss:0.44168	train-auc:0.86939	train-logloss:0.43487
# [113]	eval-auc:0.86569	eval-logloss:0.44166	train-auc:0.86948	train-logloss:0.43477
# [114]	eval-auc:0.86570	eval-logloss:0.44165	train-auc:0.86951	train-logloss:0.43472
# [115]	eval-auc:0.86570	eval-logloss:0.44165	train-auc:0.86953	train-logloss:0.43469
# [116]	eval-auc:0.86570	eval-logloss:0.44165	train-auc:0.86954	train-logloss:0.43467
# [117]	eval-auc:0.86572	eval-logloss:0.44162	train-auc:0.86960	train-logloss:0.43459
# [118]	eval-auc:0.86572	eval-logloss:0.44161	train-auc:0.86961	train-logloss:0.43454
# [119]	eval-auc:0.86572	eval-logloss:0.44162	train-auc:0.86961	train-logloss:0.43453
# [120]	eval-auc:0.86575	eval-logloss:0.44158	train-auc:0.86970	train-logloss:0.43442
# [121]	eval-auc:0.86575	eval-logloss:0.44157	train-auc:0.86973	train-logloss:0.43439
# [122]	eval-auc:0.86576	eval-logloss:0.44155	train-auc:0.86982	train-logloss:0.43427
# [123]	eval-auc:0.86576	eval-logloss:0.44155	train-auc:0.86983	train-logloss:0.43425
# [124]	eval-auc:0.86576	eval-logloss:0.44155	train-auc:0.86983	train-logloss:0.43424
# [125]	eval-auc:0.86576	eval-logloss:0.44155	train-auc:0.86985	train-logloss:0.43421
# [126]	eval-auc:0.86577	eval-logloss:0.44154	train-auc:0.86989	train-logloss:0.43414
# [127]	eval-auc:0.86577	eval-logloss:0.44154	train-auc:0.86991	train-logloss:0.43411
# [128]	eval-auc:0.86578	eval-logloss:0.44152	train-auc:0.86992	train-logloss:0.43409
# [129]	eval-auc:0.86578	eval-logloss:0.44152	train-auc:0.86994	train-logloss:0.43406
# [130]	eval-auc:0.86578	eval-logloss:0.44152	train-auc:0.86994	train-logloss:0.43405
# [131]	eval-auc:0.86579	eval-logloss:0.44151	train-auc:0.86998	train-logloss:0.43400
# [132]	eval-auc:0.86579	eval-logloss:0.44151	train-auc:0.86998	train-logloss:0.43398
# [133]	eval-auc:0.86579	eval-logloss:0.44151	train-auc:0.86999	train-logloss:0.43396
# [134]	eval-auc:0.86579	eval-logloss:0.44151	train-auc:0.87001	train-logloss:0.43395
# [135]	eval-auc:0.86579	eval-logloss:0.44151	train-auc:0.87005	train-logloss:0.43390
# [136]	eval-auc:0.86579	eval-logloss:0.44150	train-auc:0.87008	train-logloss:0.43386
# [137]	eval-auc:0.86579	eval-logloss:0.44150	train-auc:0.87008	train-logloss:0.43385
# [138]	eval-auc:0.86579	eval-logloss:0.44150	train-auc:0.87009	train-logloss:0.43384
# [139]	eval-auc:0.86579	eval-logloss:0.44150	train-auc:0.87009	train-logloss:0.43382
# [140]	eval-auc:0.86578	eval-logloss:0.44150	train-auc:0.87010	train-logloss:0.43381
# [141]	eval-auc:0.86579	eval-logloss:0.44150	train-auc:0.87011	train-logloss:0.43377
# [142]	eval-auc:0.86579	eval-logloss:0.44150	train-auc:0.87012	train-logloss:0.43375
# [143]	eval-auc:0.86579	eval-logloss:0.44150	train-auc:0.87015	train-logloss:0.43371
# [144]	eval-auc:0.86578	eval-logloss:0.44150	train-auc:0.87016	train-logloss:0.43370
# [145]	eval-auc:0.86580	eval-logloss:0.44148	train-auc:0.87023	train-logloss:0.43362
# [146]	eval-auc:0.86581	eval-logloss:0.44146	train-auc:0.87028	train-logloss:0.43352
# [147]	eval-auc:0.86582	eval-logloss:0.44144	train-auc:0.87033	train-logloss:0.43345
# [148]	eval-auc:0.86583	eval-logloss:0.44143	train-auc:0.87036	train-logloss:0.43339
# [149]	eval-auc:0.86582	eval-logloss:0.44143	train-auc:0.87039	train-logloss:0.43335

# %%
y_predH = bstH.predict(dtestH)
print(roc_auc_score(y_test,y_predH))

resultsH = progressH
x_axis = range(0, 150)
# plot log loss
fig, ax = plt.subplots(figsize=(7,7))
ax.plot(x_axis, resultsH['train']['logloss'], label='Train')
ax.plot(x_axis, resultsH['eval']['logloss'], label='Val')
ax.legend()
plt.ylabel('Log Loss')
plt.title('XGBoost Log Loss')
plt.show()
# Out:
# 0.8654273002932391
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-7517a1ffe824> in <module>
#       6 # plot log loss
#       7 fig, ax = plt.subplots(figsize=(7,7))
# ----> 8 ax.plot(x_axis, resultsH['train']['logloss'], label='Train')
#       9 ax.plot(x_axis, resultsH['eval']['logloss'], label='Val')
#      10 ax.legend()
#
# KeyError: 'train'

# %%
# calculate roc curves
fpr, tpr, _ = roc_curve(y_test, y_pred)
fprL, tprL, _ = roc_curve(y_test, y_predL)
fprH, tprH, _ = roc_curve(y_test, y_predH)

# plot the roc curve for the model
plt.plot(fpr, tpr, linestyle='--', label='all features')
plt.plot(fprL, tprL, color='m', label='low features')
plt.plot(fprH, tprH, label='high features')
# axis labels

# show the legend
plt.legend()
# show the plot
plt.show()

auc = roc_auc_score(y_test, y_pred)
aucL = roc_auc_score(y_test, y_predL)
aucH = roc_auc_score(y_test, y_predH)
print("all features AUC: %.3f" % auc)
print("low features AUC: %.3f" % aucL) 
print("high features AUC: %.3f" % aucH) 


results = progress
x_axis = range(0, 150)

# plot log loss
fig, ax = plt.subplots(figsize=(7,7))
ax.plot(x_axis, results['eval']['logloss'], label='Val')
ax.plot(x_axis, results['train']['logloss'], label='Train')
ax.legend()
plt.ylabel('Log Loss')
plt.title('XGBoost Log Loss')
plt.show()
# Out:
# all features AUC: 0.877
# low features AUC: 0.871
# high features AUC: 0.865
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-a350662f407d> in <module>
#      31 # plot log loss
#      32 fig, ax = plt.subplots(figsize=(7,7))
# ---> 33 ax.plot(x_axis, resultsH['train']['logloss'], label='Train')
#      34 ax.plot(x_axis, resultsH['eval']['logloss'], label='Val')
#      35 ax.legend()
#
# KeyError: 'train'

# %% [markdown]
# As it is possible to see, the high level features seems to give more information to the algorithm with respest to the low level ones, even if in a small extent.

# %% [markdown]
# # 2) Shallow NN with Keras

# %% [markdown]
# I will follow now the same path traced with the BDT algorithm, hence i define the model using hyperparameters founded with a Randomized Cross Validation on the all-features dataset. I choose the Randomized Search more than the Grid Search beacause it is enough accurate and it is less expensive in terms of time, which, given the high number of events in the dataset, is desirable.

# %%
# Hyperparameters
def build_classifier(optimizer, units):

    NN=Sequential()

    NN.add(Dense(units=units, activation="relu", kernel_initializer="random_uniform", input_dim=18))
    NN.add(Dense(units=1, activation="sigmoid", kernel_initializer="random_uniform"))

    NN.summary()

    

    NN.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['AUC'])
    return NN



NN = KerasClassifier(build_fn=build_classifier)

parameters ={'batch_size':[20, 32],
            'nb_epoch':[10,20,50],
            'optimizer':['adam','rmsprop','SGD'],
            'units':[300, 1000, 2000, 10000],
            #'learning_rate': [0.05, 0.005, 0.0005]
            }

grid_rndm= RandomizedSearchCV(estimator=NN, param_distributions=parameters, scoring='roc_auc', n_iter=20, n_jobs=-1, cv=3)

# tune the hyperparameters via a randomized search
grid_rndm.fit(x_train, y_train)
# evaluate the best randomized searched model on the testing
# data
print("[INFO] grid search AUC: {:.2f}".format(grid_rndm.best_score_))
print("[INFO] randomized search best parameters: {}".format(
	grid_rndm.best_params_))

# %% [markdown]
# Results:
#
# [INFO] grid search AUC: 0.87
#
#
# [INFO] randomized search best parameters: {'units': 1000, 'optimizer': 'adam', 'nb_epoch': 10, 'batch_size': 32}

# %% [markdown]
# --------------------------------------------------------------------------------
#
# Given these hyperparameters, after some trials i have found that the best learning rate to use is 0.001, hence i can now train the model on the training dataset with all the features. I use also the validation set in order then to compare the loss of the train set with respect to the validation one.
#
# In order to improve the performance, i modify the alpha value of the relu activation function, such that the problem fo the vanishing gradient is reduced and the model improved.

# %%
# Hyperparameters
learning_rate=0.001

model = Sequential()

activations.relu(x, alpha=0.1, max_value=None, threshold=0)
model.add(Dense(units=1000, kernel_initializer='he_normal', activation="relu",input_dim=18))
model.add(Dense(units=1, kernel_initializer='random_normal', activation="sigmoid"))

model.summary()

from ann_visualizer.visualize import ann_viz
ann_viz(model, view=True, filename="network.gv", title="Shallow Network")

model.compile(optimizer=Adam(learning_rate), loss='binary_crossentropy', metrics="AUC")

history = model.fit(x=x_train, y=y_train, validation_data=(x_val, y_val), batch_size=32, epochs=10)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1000)              19000
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1001
# =================================================================
# Total params: 20,001
# Trainable params: 20,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 60938/60938 [==============================] - 104s 2ms/step - loss: 0.4352 - auc: 0.8707 - val_loss: 0.4278 - val_auc: 0.8755
# Epoch 2/10
# 60938/60938 [==============================] - 103s 2ms/step - loss: 0.4293 - auc: 0.8744 - val_loss: 0.4280 - val_auc: 0.8757
# Epoch 3/10
# 60938/60938 [==============================] - 99s 2ms/step - loss: 0.4284 - auc: 0.8749 - val_loss: 0.4277 - val_auc: 0.8760
# Epoch 4/10
# 60938/60938 [==============================] - 90s 1ms/step - loss: 0.4280 - auc: 0.8752 - val_loss: 0.4285 - val_auc: 0.8754
# Epoch 5/10
# 60938/60938 [==============================] - 88s 1ms/step - loss: 0.4276 - auc: 0.8754 - val_loss: 0.4266 - val_auc: 0.8766
# Epoch 6/10
# 60938/60938 [==============================] - 89s 1ms/step - loss: 0.4275 - auc: 0.8755 - val_loss: 0.4265 - val_auc: 0.8764
# Epoch 7/10
# 60938/60938 [==============================] - 92s 2ms/step - loss: 0.4273 - auc: 0.8756 - val_loss: 0.4262 - val_auc: 0.8767
# Epoch 8/10
# 60938/60938 [==============================] - 94s 2ms/step - loss: 0.4271 - auc: 0.8757 - val_loss: 0.4262 - val_auc: 0.8766
# Epoch 9/10
# 60938/60938 [==============================] - 98s 2ms/step - loss: 0.4270 - auc: 0.8758 - val_loss: 0.4260 - val_auc: 0.8766
# Epoch 10/10
# 60938/60938 [==============================] - 91s 1ms/step - loss: 0.4270 - auc: 0.8758 - val_loss: 0.4269 - val_auc: 0.8762

# %% [markdown]
# I will now train the model using the other two datasets: the low-level and then the high-level one.

# %%
# Hyperparameters
learning_rate=0.001

modelL = Sequential()

activations.relu(x, alpha=0.1, max_value=None, threshold=0)
modelL.add(Dense(units=1000, kernel_initializer='he_normal', activation="relu",input_dim=8))
modelL.add(Dense(units=1, kernel_initializer='random_normal', activation="sigmoid"))

modelL.summary()

from ann_visualizer.visualize import ann_viz
ann_viz(modelL, view=True, filename="network.gv", title="Shallow Network")

modelL.compile(optimizer=Adam(learning_rate), loss='binary_crossentropy', metrics="AUC")

historyL = modelL.fit(x=xL_train, y=y_train, validation_data=(xL_val, y_val), batch_size=32, epochs=10)
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_42 (Dense)             (None, 1000)              9000
# _________________________________________________________________
# dense_43 (Dense)             (None, 1)                 1001
# =================================================================
# Total params: 10,001
# Trainable params: 10,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 60938/60938 [==============================] - 105s 2ms/step - loss: 0.4511 - auc: 0.8609 - val_loss: 0.4459 - val_auc: 0.8670
# Epoch 2/10
# 60938/60938 [==============================] - 87s 1ms/step - loss: 0.4391 - auc: 0.8683 - val_loss: 0.4424 - val_auc: 0.8670
# Epoch 3/10
# 60938/60938 [==============================] - 87s 1ms/step - loss: 0.4374 - auc: 0.8693 - val_loss: 0.4352 - val_auc: 0.8711
# Epoch 4/10
# 60938/60938 [==============================] - 88s 1ms/step - loss: 0.4365 - auc: 0.8699 - val_loss: 0.4351 - val_auc: 0.8710
# Epoch 5/10
# 60938/60938 [==============================] - 88s 1ms/step - loss: 0.4360 - auc: 0.8701 - val_loss: 0.4348 - val_auc: 0.8712
# Epoch 6/10
# 60938/60938 [==============================] - 89s 1ms/step - loss: 0.4356 - auc: 0.8703 - val_loss: 0.4356 - val_auc: 0.8705
# Epoch 7/10
# 60938/60938 [==============================] - 88s 1ms/step - loss: 0.4353 - auc: 0.8705 - val_loss: 0.4363 - val_auc: 0.8715
# Epoch 8/10
# 60938/60938 [==============================] - 89s 1ms/step - loss: 0.4351 - auc: 0.8706 - val_loss: 0.4347 - val_auc: 0.8715
# Epoch 9/10
# 60938/60938 [==============================] - 89s 1ms/step - loss: 0.4347 - auc: 0.8708 - val_loss: 0.4343 - val_auc: 0.8716
# Epoch 10/10
# 60938/60938 [==============================] - 90s 1ms/step - loss: 0.4347 - auc: 0.8708 - val_loss: 0.4327 - val_auc: 0.8728loss:

# %%
# Hyperparameters
learning_rate=0.001

modelH = Sequential()

activations.relu(x, alpha=0.1, max_value=None, threshold=0)
modelH.add(Dense(units=1000, kernel_initializer='he_normal', activation="relu",input_dim=10))
modelH.add(Dense(units=1, kernel_initializer='random_normal', activation="sigmoid"))

modelH.summary()

from ann_visualizer.visualize import ann_viz
ann_viz(modelH, view=True, filename="network.gv", title="Shallow Network")

modelH.compile(optimizer=Adam(learning_rate), loss='binary_crossentropy', metrics="AUC")

historyH = modelH.fit(x=xH_train, y=y_train, validation_data=(xH_val, y_val), batch_size=32, epochs=10)
# Out:
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_44 (Dense)             (None, 1000)              11000
# _________________________________________________________________
# dense_45 (Dense)             (None, 1)                 1001
# =================================================================
# Total params: 12,001
# Trainable params: 12,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 60938/60938 [==============================] - 91s 1ms/step - loss: 0.4508 - auc: 0.8597 - val_loss: 0.4450 - val_auc: 0.8634
# Epoch 2/10
# 60938/60938 [==============================] - 91s 1ms/step - loss: 0.4448 - auc: 0.8634 - val_loss: 0.4461 - val_auc: 0.8646- - E
# Epoch 3/10
# 60938/60938 [==============================] - 92s 2ms/step - loss: 0.4440 - auc: 0.8639 - val_loss: 0.4425 - val_auc: 0.8654
# Epoch 4/10
# 60938/60938 [==============================] - 92s 2ms/step - loss: 0.4436 - auc: 0.8642 - val_loss: 0.4438 - val_auc: 0.8645
# Epoch 5/10
# 60938/60938 [==============================] - 93s 2ms/step - loss: 0.4433 - auc: 0.8645 - val_loss: 0.4427 - val_auc: 0.8658
# Epoch 6/10
# 60938/60938 [==============================] - 92s 2ms/step - loss: 0.4431 - auc: 0.8646 - val_loss: 0.4422 - val_auc: 0.8655
# Epoch 7/10
# 60938/60938 [==============================] - 93s 2ms/step - loss: 0.4430 - auc: 0.8647 - val_loss: 0.4434 - val_auc: 0.8643
# Epoch 8/10
# 60938/60938 [==============================] - 93s 2ms/step - loss: 0.4427 - auc: 0.8648 - val_loss: 0.4412 - val_auc: 0.8663
# Epoch 9/10
# 60938/60938 [==============================] - 93s 2ms/step - loss: 0.4426 - auc: 0.8649 - val_loss: 0.4442 - val_auc: 0.8654
# Epoch 10/10
# 60938/60938 [==============================] - 93s 2ms/step - loss: 0.4425 - auc: 0.8650 - val_loss: 0.4427 - val_auc: 0.8660

# %% [markdown]
# Evaluation of the model:

# %%
predictions = model.predict(x_test, batch_size=32)




N = np.arange(0, 10)
plt.style.use("ggplot")
plt.figure()
plt.plot(N, history.history["loss"], label="train_loss")
plt.plot(N, history.history["val_loss"], label="val_loss")
plt.title("Training Loss All Features")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
NL = np.arange(0, 10)
plt.style.use("ggplot")
plt.figure()
plt.plot(NL, historyL.history["loss"], label="train_loss")
plt.plot(NL, historyL.history["val_loss"], label="val_loss")
plt.title("Training Loss Low-Features")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
NH = np.arange(0, 10)
plt.style.use("ggplot")
plt.figure()
plt.plot(NH, historyH.history["loss"], label="train_loss")
plt.plot(NH, historyH.history["val_loss"], label="val_loss")
plt.title("Training Loss High-Features")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()

plt.show()
#plt.savefig("training_performance.png")

# calculate roc curves
fprNN, tprNN, _ = roc_curve(y_test, predictions)
fprLNN, tprLNN, _ = roc_curve(y_test, predictionsL)
fprHNN, tprHNN, _ = roc_curve(y_test, predictionsH)


# plot the roc curve for the model
plt.plot(fprNN, tprNN, linestyle='--', label='all features')
plt.plot(fprLNN, tprLNN, color='m', label='low features')
plt.plot(fprHNN, tprHNN, label='high features')

# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# show the legend
plt.legend()
# show the plot
plt.show()


auc = roc_auc_score(y_test, predictions)
aucL = roc_auc_score(y_test, predictionsL)
aucH = roc_auc_score(y_test, predictionsH)
print("all features AUC: %.3f" % auc)
print("low features AUC: %.3f" % aucL) 
print("high features AUC: %.3f" % aucH)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-6d42e8c93119> in <module>
#      16 plt.style.use("ggplot")
#      17 plt.figure()
# ---> 18 plt.plot(NL, historyL.history["loss"], label="train_loss")
#      19 plt.plot(NL, historyL.history["val_loss"], label="val_loss")
#      20 plt.title("Training Loss Low-Features")
#
# NameError: name 'historyL' is not defined

# %% [markdown]
# With the NN the low-level features add more information with respect to the high ones, which nevertheless helps in improving the learning capability of the algorithm (higher AUC).

# %% [markdown]
# # 3) Conclusion

# %% [markdown]
# Comparing the performances of the two algorithms, it is interesting to see that it strongly depends on which kind of dataset we use for the train. While looking at the dataset with all the features and the one with just the high-level variables the AUC scores of the BDT and the NN are almost the same, with a 0.001 point higher for the NN, the performane with the low-level ones is better when considering the NN.
#
# BDT:
#
# all features AUC: 0.877
# low features AUC: 0.871
# high features AUC: 0.865
#
# NN:
#
# all features AUC: 0.876
# low features AUC: 0.872
# high features AUC: 0.866
